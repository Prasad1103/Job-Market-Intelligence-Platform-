# %%
import pandas as pd
import numpy as np

# Display all columns
pd.set_option("display.max_columns", None)

# Display wider tables
pd.set_option("display.width", 150)

# %%
clean_jobs = pd.read_csv("../data/raw/clean_jobs.csv")
gsearch_jobs = pd.read_csv("../data/raw/gsearch_jobs.csv")

# %%
print("Clean Jobs Dataset Shape:", clean_jobs.shape)
print("Google Search Jobs Dataset Shape:", gsearch_jobs.shape)
# Out:
# Clean Jobs Dataset Shape: (1048, 10)
# Google Search Jobs Dataset Shape: (61953, 27)

# %%
clean_jobs.head()
# Out:
#    id            title    company           location                                               link    source date_posted  work_type  \
# 0   1     Data Analyst       Meta       New York, NY  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14        NaN
# 1   2     Data Analyst       Meta  San Francisco, CA  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14        NaN
# 2   3     Data Analyst       Meta    Los Angeles, CA  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14        NaN
# 3   4     Data Analyst       Meta     Washington, DC  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14        NaN
# 4   5  Data Analyst II  Pinterest        Chicago, IL  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-16        NaN
#
#    employment_type                                        description
# 0              NaN  The Social Measurement team is a growing team ...
# ...

# %%
gsearch_jobs.head()
# Out:
#    Unnamed: 0  index                                             title                company_name            location           via  \
# 0           0      0                                      Data Analyst                        Meta           Anywhere   via LinkedIn
# 1           1      1                                      Data Analyst                         ATC    United States     via LinkedIn
# 2           2      2                         Aeronautical Data Analyst  Garmin International, Inc.       Olathe, KS       via Indeed
# 3           3      3  Data Analyst - Consumer Goods - Contract to Hire                      Upwork           Anywhere     via Upwork
# 4           4      4               Data Analyst | Workforce Management                Krispy Kreme    United States     via LinkedIn
#
#                                          description                                         extensions  \
# ...

# %%
print("Google Search Columns")
print(gsearch_jobs.columns.tolist())
# Out:
# Google Search Columns
# ['Unnamed: 0', 'index', 'title', 'company_name', 'location', 'via', 'description', 'extensions', 'job_id', 'thumbnail', 'posted_at', 'schedule_type', 'work_from_home', 'salary', 'search_term', 'date_time', 'search_location', 'commute_time', 'salary_pay', 'salary_rate', 'salary_avg', 'salary_min', 'salary_max', 'salary_hourly', 'salary_yearly', 'salary_standardized', 'description_tokens']

# %%
print("Clean Jobs Columns")
print(clean_jobs.columns.tolist())
# Out:
# Clean Jobs Columns
# ['id', 'title', 'company', 'location', 'link', 'source', 'date_posted', 'work_type', 'employment_type', 'description']

# %%
clean_jobs.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1048 non-null   int64
#  1   title            1048 non-null   str
#  2   company          1046 non-null   str
#  3   location         1033 non-null   str
#  4   link             1048 non-null   str
#  5   source           959 non-null    str
#  6   date_posted      1025 non-null   str
#  7   work_type        0 non-null      float64
#  8   employment_type  0 non-null      float64
#  9   description      1044 non-null   str
# dtypes: float64(2), int64(1), str(7)
# memory usage: 4.5 MB

# %%
gsearch_jobs.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 61953 entries, 0 to 61952
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           61953 non-null  int64
#  1   index                61953 non-null  int64
#  2   title                61953 non-null  str
#  3   company_name         61953 non-null  str
#  4   location             61916 non-null  str
#  5   via                  61944 non-null  str
#  6   description          61953 non-null  str
#  7   extensions           61953 non-null  str
#  8   job_id               61953 non-null  str
#  9   thumbnail            38194 non-null  str
#  10  posted_at            61763 non-null  str
#  11  schedule_type        61707 non-null  str
#  12  work_from_home       27980 non-null  object
#  13  salary               10088 non-null  str
#  14  search_term          61953 non-null  str
#  15  date_time            61953 non-null  str
# ...

# %%
clean_jobs.isnull().sum().sort_values(ascending=False)
# Out:
# work_type          1048
# employment_type    1048
# source               89
# date_posted          23
# location             15
# description           4
# company               2
# id                    0
# title                 0
# link                  0
# dtype: int64

# %%
gsearch_jobs.isnull().sum().sort_values(ascending=False)
# Out:
# commute_time           61953
# salary_yearly          57884
# salary_hourly          56053
# salary_max             52441
# salary_min             52441
# salary                 51865
# salary_pay             51865
# salary_rate            51865
# salary_standardized    51865
# salary_avg             51865
# work_from_home         33973
# thumbnail              23759
# schedule_type            246
# posted_at                190
# location                  37
# via                        9
# index                      0
# title                      0
# Unnamed: 0                 0
# extensions                 0
# job_id                     0
# company_name               0
# description                0
# date_time                  0
# search_location            0
# search_term                0
# description_tokens         0
# dtype: int64

# %%
print("Clean Jobs:", clean_jobs.duplicated().sum())
# Out:
# Clean Jobs: 0

# %%
print("Google Search:", gsearch_jobs.duplicated().sum())
# Out:
# Google Search: 0

# %%
clean_jobs.describe(include="all")
# Out:
#                  id         title company       location                                               link    source date_posted  work_type  \
# count   1048.000000          1048    1046           1033                                               1048       959        1025        0.0
# unique          NaN           523     632            358                                               1048         3          36        NaN
# top             NaN  Data Analyst    Meta  United States  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-06-06        NaN
# freq            NaN           152      70             73                                                  1       862         108        NaN
# mean    1314.083969           NaN     NaN            NaN                                                NaN       NaN         NaN        NaN
# ...

# %%
gsearch_jobs.describe(include="all")
# Out:
#           Unnamed: 0         index         title company_name    location           via                                        description  \
# count   61953.000000  61953.000000         61953        61953       61916         61944                                              61953
# unique           NaN           NaN         23292        13429        1254          1024                                              42976
# top              NaN           NaN  Data Analyst       Upwork   Anywhere   via LinkedIn  The Sr. Data Analyst, Marketing Operations wil...
# freq             NaN           NaN          6444         7533       18067         20475                                                258
# mean    30976.000000   1139.077333           NaN          NaN         NaN           NaN                                                NaN
# std     17884.434951    690.256113           NaN          NaN         NaN           NaN                                                NaN
# ...

# %%
clean_jobs.sample(5)
# Out:
#        id                                              title                           company                     location  \
# 961  2367  Sr. Analyst, Retail Global Analytics and Insig...  Universal Products & Experiences           Universal City, CA
# 490  1258          Sr. Data Scientist (Commercial Analytics)                             Cedar                United States
# 346   863                      Sr. Analyst, Data & Analytics            Authentic Brands Group                 New York, NY
# 563  1473                                      Data Engineer                       Middle Seat               Washington, DC
# 638  1649                 **** ********* (******* *********)                             *****  *********, *********, *****
#
#                                                   link    source date_posted  work_type  employment_type  \
# 961      https://www.linkedin.com/jobs/view/4230884297  linkedin         NaN        NaN              NaN
# ...

# %%
gsearch_jobs.sample(5)
# Out:
#        Unnamed: 0  index                                              title              company_name              location           via  \
# 28186       28186   1159  Data Analytics Expert - First Party Fraud Prev...                      USAA  Colorado Springs, CO         BeBee
# 52921       52921    171                             Data Reporting Analyst              Confidential              Anywhere  via LinkedIn
# 28296       28296   1269                                       Data Analyst  Morgan Community College       Fort Morgan, CO         BeBee
# 27119       27119     92        Weekend Data Analyst for US Market Insights                       Yoh         United States         BeBee
# 54645       54645   1895                                  Data Science Lead             Invenia Group              Anywhere  via LinkedIn
#
#                                              description                                         extensions  \
# ...
